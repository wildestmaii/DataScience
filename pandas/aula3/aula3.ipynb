# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dias = [1, 2, 3, 4, 5]
dormir = [7, 8, 6, 77, 7]
comer = [2, 3, 4, 5, 3]
trabalhar = [7, 8, 7, 2, 2]
passear = [8, 5, 7, 8, 13]

# %%
plt.stackplot(dias, dormir, comer, trabalhar, passear, 
              labels = ['dias','dormir','comer','trabalhar','passear'], colors = ['m','c','r','k','b'])
plt.legend(loc = 'upper left')
plt.show()

# %%
porcentagens = [70, 20, 20, 130]
cidades = ['São Paulo', 'Recife', 'Fortaleza', 'Manaus']
colunas = ['c', 'm', 'r', 'k'] # cores usadas no plot

# %%
plt.pie(porcentagens, labels = cidades, colors = colunas, startangle = 90, shadow = True, explode = (0,0.15,0,0))
plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(np.random.randn(50), color = 'red')

ax2 = fig.add_subplot(1, 2, 2) #scatterplot
ax2.scatter(np.arange(50), np.random.randn(50))
plt.show()

# %%
x = np.linespace(0, 1., 100)
fig, axes = plt.subplots(1, 2, figsize = (12,4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("Eixo com range padrão")

x = np.linspace(-1, 1., 100)
axes[1].plot(x, x**2, x, x**3)
axes[1].set_ylim([0, 1])            # Especifico o tamanho do eixo y
axes[1].set_xlim([-1, 1])           # Especifico o tamanho do eixo x
axes[1].set_title("Eixos customizados")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /workspaces/DataScience/pandas/aula3/aula3.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bfictional-space-train-4wx7pjgwpjpcjrj5/workspaces/DataScience/pandas/aula3/aula3.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> x = np.linespace(0, 1., 100)
#       <a href='vscode-notebook-cell://codespaces%2Bfictional-space-train-4wx7pjgwpjpcjrj5/workspaces/DataScience/pandas/aula3/aula3.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> fig, axes = plt.subplots(1, 2, figsize = (12,4))
#       <a href='vscode-notebook-cell://codespaces%2Bfictional-space-train-4wx7pjgwpjpcjrj5/workspaces/DataScience/pandas/aula3/aula3.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> axes[0].plot(x, x**2, x, x**3)
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:328, in __getattr__(attr)
#     325     "Removed in NumPy 1.25.0"
#     326     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 328 raise AttributeError("module {!r} has no attribute "
#     329                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'linespace'

# %%
# Out:
#   Cell In[14], line 1
#     )
#     ^
# SyntaxError: unmatched ')'
